# %%
from graphviz import Digraph

# %%
graph = Digraph()
graph.attr('graph', overlap='scale')
graph.attr('node', shape='plain')
graph.attr('edge', arrowhead='none')

# %%
graph.node(name='A', label='Start: Northern Undead Asylum')
graph.node(name='B', label='Priscilla Boss Fight')
graph.node(name='C', label='Beginning of the Painted World of Ariamis')
graph.node(name='D', label='Lost Izalith: just before Bed of Chaos')
graph.node(name='E', label='Painted World of Ariamis: in the castle')
graph.node(name='F', label='Ornstein and Smough Boss Fight')
graph.node(name='G', label='Tomb of the Giants: Just before Nito')
graph.node(name='H', label='Firelink')
graph.node(name='I', label='Iron Golem Boss Fight')
graph.node(name='J', label='Ceaseless Discharge Boss Fight')
graph.node(name='K', label='Royal Woods')
graph.node(name='L', label='Northen Undead Asylum: Crow')
graph.node(name='M', label='Anor Londo: Church with Painting')
graph.node(name='N', label='Bed of Chaos Boss Fight')
graph.node(name='O', label="The Duke's Archives Outside")
graph.node(name='P', label='Quelaag Boss Fight')
graph.node(name='Q', label='Gwyndolin Boss Fight')
graph.node(name='R', label='Sif Boss Fight')
graph.node(name='S', label='Anor Londo: Outdoors')
graph.node(name='T', label='Tomb of the Giants')
graph.node(name='U', label='New Londo Ruins')
graph.node(name='V', label='The Great Hollow: Ash Lake')
graph.node(name='W', label='Northern Undead Asylum: Oscar')
graph.node(name='X', label="Sen's Fortress: Other side of Iron Golem")
graph.node(name='Y', label='Seath the Scaleless Boss Fight')
graph.node(name='Z', label='Gwyn Boss Fight')
graph.node(name='AA', label='Manus Boss Fight')
graph.node(name='AB', label="The Duke's Archives: Before first Seath Fight")
graph.node(name='AC', label='Depths: Above Gaping Dragon')
graph.node(name='AD', label='Nito Boss Fight')
graph.node(name='AE', label='Chasm of the Abyss: Before Manus Fight')
graph.node(name='AF', label='Demon Ruins: Bottom of Lava Pit')
graph.node(name='AG', label='Pinwheel Boss Fight')
graph.node(name='AH', label='Blighttown: Midpoint')
graph.node(name='AI', label='First Seath Fight')
graph.node(name='AJ', label='Taurus Boss Fight')
graph.node(name='AK', label='Four Kings Boss Fight')
graph.node(name='AL', label='Gaping Dragon Boss Fight')
graph.node(name='AM', label='Asylum Demon Boss Fight')
graph.node(name='AN', label='Artorias Boss Fight')
graph.node(name='AO', label='Anor Londo: Stairs after Ornstein and Smough Fight')
graph.node(name='AP', label='Demon Ruins: Including Firesage Boss Fight')
graph.node(name='AQ', label='Gargoyles Boss Fight')
graph.node(name='AR', label="The Duke's Archive: Opening")
graph.node(name='AS', label='Centipede Demon Boss Fight')
graph.node(name='AT', label='Anor Londo: Inside House')
graph.node(name='AU', label='Santuary Garden')
graph.node(name='AV', label='Moonlight Butterfly Boss Fight')
graph.node(name='AW', label='Undead Parish: Bell Tower')
graph.node(name='AX', label='Darkroot Garden: Tower')
graph.node(name='AY', label='DarkRoot Garden: Before Moonlight Butterfly')
graph.node(name='AZ', label="Sen's Fortress: Boulder Hill")
graph.node(name='BA', label='Kalameet Boss Fight')
graph.node(name='BB', label='Sanctuary Guardian Boss Fight')
graph.node(name='BC', label='Depths')

# %%
graph.edge(tail_name='A', head_name='B')
graph.edge(tail_name='B', head_name='C')
graph.edge(tail_name='C', head_name='D')
graph.edge(tail_name='D', head_name='E')
graph.edge(tail_name='C', head_name='F')
graph.edge(tail_name='F', head_name='G')
graph.edge(tail_name='F', head_name='H')
graph.edge(tail_name='H', head_name='I')
graph.edge(tail_name='H', head_name='J')
graph.edge(tail_name='H', head_name='Z')
graph.edge(tail_name='H', head_name='Y')
graph.edge(tail_name='H', head_name='W')
graph.edge(tail_name='W', head_name='AJ')
graph.edge(tail_name='AJ', head_name='BA')
graph.edge(tail_name='H', head_name='V')
graph.edge(tail_name='H', head_name='K')
graph.edge(tail_name='K', head_name='AA')
graph.edge(tail_name='K', head_name='AB')
graph.edge(tail_name='H', head_name='T')
graph.edge(tail_name='H', head_name='S')
graph.edge(tail_name='S', head_name='AF')
graph.edge(tail_name='S', head_name='AH')
graph.edge(tail_name='S', head_name='AG')
graph.edge(tail_name='AG', head_name='BB')
graph.edge(tail_name='BB', head_name='AY')
graph.edge(tail_name='AY', head_name='AZ')
graph.edge(tail_name='H', head_name='R')
graph.edge(tail_name='H', head_name='P')
graph.edge(tail_name='P', head_name='AE')
graph.edge(tail_name='AE', head_name='AN')
graph.edge(tail_name='AN', head_name='AO')
graph.edge(tail_name='AO', head_name='AP')
graph.edge(tail_name='AP', head_name='AT')
graph.edge(tail_name='AT', head_name='AV')
graph.edge(tail_name='AV', head_name='AX')
graph.edge(tail_name='AP', head_name='AR')
graph.edge(tail_name='AP', head_name='AS')
graph.edge(tail_name='AS', head_name='BC')
graph.edge(tail_name='BC', head_name='AW')
graph.edge(tail_name='AP', head_name='AQ')
graph.edge(tail_name='AQ', head_name='AU')
graph.edge(tail_name='H', head_name='U')
graph.edge(tail_name='U', head_name='AI')
graph.edge(tail_name='AI', head_name='AU')
graph.edge(tail_name='BC', head_name='AC')
graph.edge(tail_name='H', head_name='O')
graph.edge(tail_name='O', head_name='AD')
graph.edge(tail_name='AD', head_name='H')
graph.edge(tail_name='H', head_name='L')
graph.edge(tail_name='L', head_name='AC')
graph.edge(tail_name='H', head_name='X')
graph.edge(tail_name='X', head_name='AL')
graph.edge(tail_name='X', head_name='AK')
graph.edge(tail_name='X', head_name='AM')
graph.edge(tail_name='AM', head_name='L')
graph.edge(tail_name='H', head_name='M')
graph.edge(tail_name='H', head_name='N')
graph.edge(tail_name='H', head_name='Q')

# %%
print(graph.source)
# Out:
# digraph {
# 	graph [overlap=scale]
# 	node [shape=plain]
# 	edge [arrowhead=none]
# 	A [label="Start: Northern Undead Asylum"]
# 	B [label="Priscilla Boss Fight"]
# 	C [label="Beginning of the Painted World of Ariamis"]
# 	D [label="Lost Izalith: just before Bed of Chaos"]
# 	E [label="Painted World of Ariamis: in the castle"]
# 	F [label="Ornstein and Smough Boss Fight"]
# 	G [label="Tomb of the Giants: Just before Nito"]
# 	H [label=Firelink]
# 	I [label="Iron Golem Boss Fight"]
# 	J [label="Ceaseless Discharge Boss Fight"]
# 	K [label="Royal Woods"]
# 	L [label="Northen Undead Asylum: Crow"]
# 	M [label="Anor Londo: Church with Painting"]
# 	N [label="Bed of Chaos Boss Fight"]
# 	O [label="The Duke's Archives Outside"]
# 	P [label="Quelaag Boss Fight"]
# 	Q [label="Gwyndolin Boss Fight"]
# 	R [label="Sif Boss Fight"]
# 	S [label="Anor Londo: Outdoors"]
# 	T [label="Tomb of the Giants"]
# 	U [label="New Londo Ruins"]
# 	V [label="The Great Hollow: Ash Lake"]
# ...

# %%
graph.save(filename='foggate.gv')
# Out:
# 'foggate.gv'

# %%
from graphviz import Source

# %%
Source.from_file(filename='foggate.gv', engine='neato')
